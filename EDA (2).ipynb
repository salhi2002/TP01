# %% [markdown]
# # EDA
#
# hello , this is a notebook for analysing the results.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('results.csv')

df
# Out:
#     id_test            function_name  array_length  comparison  Swaps  \
# 0         0           selection_sort           100        4950     94
# 1         0              bubble_sort           100        4950      0
# 2         0  insertion_sort_shifting           100           0      0
# 3         0  insertion_sort_exchange           100          99      0
# 4         1           selection_sort           100        4950     97
# 5         1              bubble_sort           100        4950      0
# 6         1  insertion_sort_shifting           100           0      0
# 7         1  insertion_sort_exchange           100          99      0
# 8         2           selection_sort           100        4950     94
# 9         2              bubble_sort           100        4950      0
# 10        2  insertion_sort_shifting           100           0      0
# 11        2  insertion_sort_exchange           100          99      0
# 12        3           selection_sort           300       44850    295
# 13        3              bubble_sort           300       44850      0
# 14        3  insertion_sort_shifting           300           0      0
# 15        3  insertion_sort_exchange           300         299      0
# 16        4           selection_sort           300       44850    293
# 17        4              bubble_sort           300       44850      0
# 18        4  insertion_sort_shifting           300           0      0
# 19        4  insertion_sort_exchange           300         299      0
# 20        5           selection_sort           300       44850    294
# 21        5              bubble_sort           300       44850      0
# 22        5  insertion_sort_shifting           300           0      0
# 23        5  insertion_sort_exchange           300         299      0
# 24        6           selection_sort           500      124750    496
# 25        6              bubble_sort           500      124750      0
# 26        6  insertion_sort_shifting           500           0      0
# 27        6  insertion_sort_exchange           500         499      0
# 28        7           selection_sort           500      124750    495
# 29        7              bubble_sort           500      124750      0
# 30        7  insertion_sort_shifting           500           0      0
# 31        7  insertion_sort_exchange           500         499      0
# 32        8           selection_sort           500      124750    495
# 33        8              bubble_sort           500      124750      0
# 34        8  insertion_sort_shifting           500           0      0
# 35        8  insertion_sort_exchange           500         499      0
# 36        9           selection_sort           700      244650    695
# 37        9              bubble_sort           700      244650      0
# 38        9  insertion_sort_shifting           700           0      0
# 39        9  insertion_sort_exchange           700         699      0
# 40       10           selection_sort           700      244650    692
# 41       10              bubble_sort           700      244650      0
# 42       10  insertion_sort_shifting           700           0      0
# 43       10  insertion_sort_exchange           700         699      0
# 44       11           selection_sort           700      244650    693
# 45       11              bubble_sort           700      244650      0
# 46       11  insertion_sort_shifting           700           0      0
# 47       11  insertion_sort_exchange           700         699      0
# 48       12           selection_sort           900      404550    889
# 49       12              bubble_sort           900      404550      0
# 50       12  insertion_sort_shifting           900           0      0
# 51       12  insertion_sort_exchange           900         899      0
# 52       13           selection_sort           900      404550    893
# 53       13              bubble_sort           900      404550      0
# 54       13  insertion_sort_shifting           900           0      0
# 55       13  insertion_sort_exchange           900         899      0
# 56       14           selection_sort           900      404550    894
# 57       14              bubble_sort           900      404550      0
# 58       14  insertion_sort_shifting           900           0      0
# 59       14  insertion_sort_exchange           900         899      0
#
#         time     space
# 0   0.202545  0.000000
# 1   0.201867  0.000000
# 2   0.200711  0.000000
# 3   0.201466  0.000000
# 4   0.201724  0.000000
# 5   0.202141  0.000000
# 6   0.200498  0.000000
# 7   0.201306  0.000000
# 8   0.202128  0.000000
# 9   0.201302  0.000000
# 10  0.201269  0.000000
# 11  0.200491  0.000000
# 12  0.209061  0.000000
# 13  0.209244  0.000000
# 14  0.201313  0.000000
# 15  0.201839  0.000000
# 16  0.208886  0.000000
# 17  0.208658  0.000000
# 18  0.200502  0.000000
# 19  0.201987  0.000000
# 20  0.208389  0.000000
# 21  0.210152  0.000000
# 22  0.200471  0.000000
# 23  0.200878  0.000000
# 24  0.223178  0.000000
# 25  0.223400  0.000000
# 26  0.200502  0.000000
# 27  0.200541  0.000000
# 28  0.222632  0.000000
# 29  0.223966  0.000000
# 30  0.200549  0.000000
# 31  0.201486  0.000000
# 32  0.224560  0.000000
# 33  0.224729  0.000000
# 34  0.201145  0.000000
# 35  0.201279  0.003906
# 36  0.246994  0.000000
# 37  0.247377  0.000000
# 38  0.200631  0.000000
# 39  0.200988  0.000000
# 40  0.248055  0.000000
# 41  0.248763  0.003906
# 42  0.201489  0.000000
# 43  0.201600  0.000000
# 44  0.246986  0.000000
# 45  0.245995  0.000000
# 46  0.201201  0.000000
# 47  0.201399  0.003906
# 48  0.280551  0.000000
# 49  0.277276  0.000000
# 50  0.201465  0.000000
# 51  0.201182  0.000000
# 52  0.276934  0.000000
# 53  0.276167  0.000000
# 54  0.201395  0.000000
# 55  0.201440  0.000000
# 56  0.277898  0.000000
# 57  0.275568  0.000000
# 58  0.200809  0.000000
# 59  0.201446  0.000000

# %%
group_columns = ['function_name', 'array_length']
cal_columns = ['comparison','Swaps', 'time','space']

# %%
group_df = df.groupby(group_columns,as_index=False).mean()

# %%
calculated_results = group_df[group_columns+cal_columns]

calculated_results
# Out:
#               function_name  array_length  comparison       Swaps      time  \
# 0               bubble_sort           100      4950.0    0.000000  0.201770
# 1               bubble_sort           300     44850.0    0.000000  0.209352
# 2               bubble_sort           500    124750.0    0.000000  0.224032
# 3               bubble_sort           700    244650.0    0.000000  0.247379
# 4               bubble_sort           900    404550.0    0.000000  0.276337
# 5   insertion_sort_exchange           100        99.0    0.000000  0.201088
# 6   insertion_sort_exchange           300       299.0    0.000000  0.201568
# 7   insertion_sort_exchange           500       499.0    0.000000  0.201102
# 8   insertion_sort_exchange           700       699.0    0.000000  0.201329
# 9   insertion_sort_exchange           900       899.0    0.000000  0.201356
# 10  insertion_sort_shifting           100         0.0    0.000000  0.200826
# 11  insertion_sort_shifting           300         0.0    0.000000  0.200762
# 12  insertion_sort_shifting           500         0.0    0.000000  0.200732
# 13  insertion_sort_shifting           700         0.0    0.000000  0.201107
# 14  insertion_sort_shifting           900         0.0    0.000000  0.201223
# 15           selection_sort           100      4950.0   95.000000  0.202132
# 16           selection_sort           300     44850.0  294.000000  0.208779
# 17           selection_sort           500    124750.0  495.333333  0.223456
# 18           selection_sort           700    244650.0  693.333333  0.247345
# 19           selection_sort           900    404550.0  892.000000  0.278461
#
#        space
# 0   0.000000
# 1   0.000000
# 2   0.000000
# 3   0.001302
# 4   0.000000
# 5   0.000000
# 6   0.000000
# 7   0.001302
# 8   0.001302
# 9   0.000000
# 10  0.000000
# 11  0.000000
# 12  0.000000
# 13  0.000000
# 14  0.000000
# 15  0.000000
# 16  0.000000
# 17  0.000000
# 18  0.000000
# 19  0.000000

# %%
function_names = list(calculated_results['function_name'].unique())
function_names
# Out:
# ['bubble_sort',
#  'insertion_sort_exchange',
#  'insertion_sort_shifting',
#  'selection_sort']

# %%
for function_name in function_names:
    df_plot = calculated_results[calculated_results['function_name'] == function_name]
    plt.plot(df_plot['array_length'], df_plot['comparison'],label=function_name)

# %%
calculated_results[calculated_results['function_name'] == 'bubble_sort']['comparison'].describe()
# Out:
# count         5.000000
# mean     164750.000000
# std      162326.907813
# min        4950.000000
# 25%       44850.000000
# 50%      124750.000000
# 75%      244650.000000
# max      404550.000000
# Name: comparison, dtype: float64

# %%
calculated_results[calculated_results['function_name'] == 'insertion_sort_exchange']['comparison'].describe()
# Out:
# count      5.000000
# mean     499.000000
# std      316.227766
# min       99.000000
# 25%      299.000000
# 50%      499.000000
# 75%      699.000000
# max      899.000000
# Name: comparison, dtype: float64

# %%
calculated_results[calculated_results['function_name'] == 'insertion_sort_shifting']['comparison'].describe()
# Out:
# count    5.0
# mean     0.0
# std      0.0
# min      0.0
# 25%      0.0
# 50%      0.0
# 75%      0.0
# max      0.0
# Name: comparison, dtype: float64

# %%
calculated_results[calculated_results['function_name'] == 'selection_sort']['comparison'].describe()
# Out:
# count         5.000000
# mean     164750.000000
# std      162326.907813
# min        4950.000000
# 25%       44850.000000
# 50%      124750.000000
# 75%      244650.000000
# max      404550.000000
# Name: comparison, dtype: float64

# %%
df_plot = calculated_results[calculated_results['function_name'] == 'insertion_sort_shifting']

# %%
from complexity import get_complexity

x_plot = df_plot['array_length']
y_plot = df_plot['comparison'] 

get_complexity(x_plot,y_plot)
# Out:
# c:\Users\CORTEC\Downloads\Telegram Desktop\complexity.py:24: RuntimeWarning: invalid value encountered in scalar divide
#   rms = np.sqrt(((y - coef * func(x))** 2).mean()) / y.mean()
# c:\Users\CORTEC\Downloads\Telegram Desktop\complexity.py:24: RuntimeWarning: invalid value encountered in scalar divide
#   rms = np.sqrt(((y - coef * func(x))** 2).mean()) / y.mean()
# c:\Users\CORTEC\Downloads\Telegram Desktop\complexity.py:24: RuntimeWarning: invalid value encountered in scalar divide
#   rms = np.sqrt(((y - coef * func(x))** 2).mean()) / y.mean()
# c:\Users\CORTEC\Downloads\Telegram Desktop\complexity.py:24: RuntimeWarning: invalid value encountered in scalar divide
#   rms = np.sqrt(((y - coef * func(x))** 2).mean()) / y.mean()
# 'O(1)'
